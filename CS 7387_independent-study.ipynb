# %%
# %cd /content/drive/MyDrive/CS 7389G
# Out:
# /content/drive/MyDrive/CS 7389G

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import tensorflow as tf

# %%
df1_adm=pd.read_csv("admissions.csv")
df1_adm
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1         10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2         10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3         10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 4         10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...            ...       ...                  ...                  ...
# 431226    19999828  25744818  2149-01-08 16:44:00  2149-01-18 17:00:00
# 431227    19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 431228    19999840  21033226  2164-09-10 13:47:00  2164-09-17 13:42:00
# 431229    19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 431230    19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#                   deathtime  admission_type admit_provider_id  \
# 0                       NaN          URGENT            P874LG
# 1                       NaN        EW EMER.            P09Q6Y
# 2                       NaN        EW EMER.            P60CC5
# 3                       NaN        EW EMER.            P30KEH
# 4                       NaN  EU OBSERVATION            P51VDL
# ...                     ...             ...               ...
# 431226                  NaN        EW EMER.            P75BG6
# 431227                  NaN        EW EMER.            P16C7J
# 431228  2164-09-17 13:42:00        EW EMER.            P58A9J
# 431229                  NaN        EW EMER.            P506DE
# 431230                  NaN        EW EMER.            P09IS0
#
#             admission_location discharge_location insurance language  \
# 0       TRANSFER FROM HOSPITAL               HOME     Other  ENGLISH
# 1               EMERGENCY ROOM               HOME  Medicaid  ENGLISH
# 2               EMERGENCY ROOM            HOSPICE  Medicaid  ENGLISH
# 3               EMERGENCY ROOM               HOME  Medicaid  ENGLISH
# 4               EMERGENCY ROOM                NaN     Other  ENGLISH
# ...                        ...                ...       ...      ...
# 431226  TRANSFER FROM HOSPITAL   HOME HEALTH CARE     Other  ENGLISH
# 431227      PHYSICIAN REFERRAL   HOME HEALTH CARE     Other  ENGLISH
# 431228          EMERGENCY ROOM               DIED     Other  ENGLISH
# 431229          EMERGENCY ROOM               HOME     Other  ENGLISH
# 431230          EMERGENCY ROOM              REHAB     Other  ENGLISH
#
#        marital_status     race            edregtime            edouttime  \
# 0             WIDOWED    WHITE  2180-05-06 19:17:00  2180-05-06 23:30:00
# 1             WIDOWED    WHITE  2180-06-26 15:54:00  2180-06-26 21:31:00
# 2             WIDOWED    WHITE  2180-08-05 20:58:00  2180-08-06 01:44:00
# 3             WIDOWED    WHITE  2180-07-23 05:54:00  2180-07-23 14:00:00
# 4              SINGLE    WHITE  2160-03-03 21:55:00  2160-03-04 06:26:00
# ...               ...      ...                  ...                  ...
# 431226         SINGLE    WHITE  2149-01-08 09:11:00  2149-01-08 18:12:00
# 431227         SINGLE    WHITE  2147-07-17 17:18:00  2147-07-18 17:34:00
# 431228        WIDOWED    WHITE  2164-09-10 11:09:00  2164-09-10 14:46:00
# 431229        WIDOWED    WHITE  2164-07-24 21:16:00  2164-07-25 01:20:00
# 431230            NaN  UNKNOWN  2145-11-02 19:28:00  2145-11-02 22:59:00
#
#         hospital_expire_flag
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 431226                     0
# 431227                     0
# 431228                     1
# 431229                     0
# 431230                     0
#
# [431231 rows x 16 columns]

# %%
df1_adm=df1_adm.drop(columns=['admit_provider_id', 'edregtime', 'edouttime', 'hospital_expire_flag'])
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1         10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2         10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3         10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 4         10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...            ...       ...                  ...                  ...
# 431226    19999828  25744818  2149-01-08 16:44:00  2149-01-18 17:00:00
# 431227    19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 431228    19999840  21033226  2164-09-10 13:47:00  2164-09-17 13:42:00
# 431229    19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 431230    19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#                   deathtime  admission_type      admission_location  \
# 0                       NaN          URGENT  TRANSFER FROM HOSPITAL
# 1                       NaN        EW EMER.          EMERGENCY ROOM
# 2                       NaN        EW EMER.          EMERGENCY ROOM
# 3                       NaN        EW EMER.          EMERGENCY ROOM
# 4                       NaN  EU OBSERVATION          EMERGENCY ROOM
# ...                     ...             ...                     ...
# 431226                  NaN        EW EMER.  TRANSFER FROM HOSPITAL
# 431227                  NaN        EW EMER.      PHYSICIAN REFERRAL
# 431228  2164-09-17 13:42:00        EW EMER.          EMERGENCY ROOM
# 431229                  NaN        EW EMER.          EMERGENCY ROOM
# 431230                  NaN        EW EMER.          EMERGENCY ROOM
#
#        discharge_location insurance language marital_status     race
# 0                    HOME     Other  ENGLISH        WIDOWED    WHITE
# 1                    HOME  Medicaid  ENGLISH        WIDOWED    WHITE
# 2                 HOSPICE  Medicaid  ENGLISH        WIDOWED    WHITE
# 3                    HOME  Medicaid  ENGLISH        WIDOWED    WHITE
# 4                     NaN     Other  ENGLISH         SINGLE    WHITE
# ...                   ...       ...      ...            ...      ...
# 431226   HOME HEALTH CARE     Other  ENGLISH         SINGLE    WHITE
# 431227   HOME HEALTH CARE     Other  ENGLISH         SINGLE    WHITE
# 431228               DIED     Other  ENGLISH        WIDOWED    WHITE
# 431229               HOME     Other  ENGLISH        WIDOWED    WHITE
# 431230              REHAB     Other  ENGLISH            NaN  UNKNOWN
#
# [431231 rows x 12 columns]

# %%
df2_icu=pd.read_csv("icustays.csv")
df2_icu
# Out:
#        subject_id   hadm_id   stay_id  \
# 0        10000032  29079034  39553978
# 1        10000980  26913865  39765666
# 2        10001217  24597018  37067082
# 3        10001217  27703517  34592300
# 4        10001725  25563031  31205490
# ...           ...       ...       ...
# 73176    19999442  26785317  32336619
# 73177    19999625  25304202  31070865
# 73178    19999828  25744818  36075953
# 73179    19999840  21033226  38978960
# 73180    19999987  23865745  36195440
#
#                                          first_careunit  \
# 0                    Medical Intensive Care Unit (MICU)
# 1                    Medical Intensive Care Unit (MICU)
# 2                   Surgical Intensive Care Unit (SICU)
# 3                   Surgical Intensive Care Unit (SICU)
# 4      Medical/Surgical Intensive Care Unit (MICU/SICU)
# ...                                                 ...
# 73176               Surgical Intensive Care Unit (SICU)
# 73177  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 73178                Medical Intensive Care Unit (MICU)
# 73179                               Trauma SICU (TSICU)
# 73180                               Trauma SICU (TSICU)
#
#                                           last_careunit            intime  \
# 0                    Medical Intensive Care Unit (MICU)   7/23/2180 14:00
# 1                    Medical Intensive Care Unit (MICU)    6/27/2189 8:42
# 2                   Surgical Intensive Care Unit (SICU)  11/20/2157 19:18
# 3                   Surgical Intensive Care Unit (SICU)  12/19/2157 15:42
# 4      Medical/Surgical Intensive Care Unit (MICU/SICU)   4/11/2110 15:52
# ...                                                 ...               ...
# 73176               Surgical Intensive Care Unit (SICU)  11/19/2148 14:23
# 73177  Medical/Surgical Intensive Care Unit (MICU/SICU)  10/10/2139 19:18
# 73178                Medical Intensive Care Unit (MICU)    1/8/2149 18:12
# 73179               Surgical Intensive Care Unit (SICU)    9/12/2164 9:26
# 73180                               Trauma SICU (TSICU)   11/2/2145 22:59
#
#                 outtime
# 0       7/23/2180 23:50
# 1       6/27/2189 20:38
# 2      11/21/2157 22:08
# 3      12/20/2157 14:27
# 4       4/12/2110 23:59
# ...                 ...
# 73176  11/26/2148 13:12
# 73177  10/11/2139 18:21
# 73178   1/10/2149 13:11
# 73179   9/17/2164 16:35
# 73180   11/4/2145 21:29
#
# [73181 rows x 7 columns]

# %%
df_merged = df1_adm.merge(df2_icu, how='outer')
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1         10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2         10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3         10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 4         10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...            ...       ...                  ...                  ...
# 438168    19999828  25744818  2149-01-08 16:44:00  2149-01-18 17:00:00
# 438169    19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 438170    19999840  21033226  2164-09-10 13:47:00  2164-09-17 13:42:00
# 438171    19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 438172    19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#                   deathtime  admission_type      admission_location  \
# 0                       NaN          URGENT  TRANSFER FROM HOSPITAL
# 1                       NaN        EW EMER.          EMERGENCY ROOM
# 2                       NaN        EW EMER.          EMERGENCY ROOM
# 3                       NaN        EW EMER.          EMERGENCY ROOM
# 4                       NaN  EU OBSERVATION          EMERGENCY ROOM
# ...                     ...             ...                     ...
# 438168                  NaN        EW EMER.  TRANSFER FROM HOSPITAL
# 438169                  NaN        EW EMER.      PHYSICIAN REFERRAL
# 438170  2164-09-17 13:42:00        EW EMER.          EMERGENCY ROOM
# 438171                  NaN        EW EMER.          EMERGENCY ROOM
# 438172                  NaN        EW EMER.          EMERGENCY ROOM
#
#        discharge_location insurance language marital_status     race  \
# 0                    HOME     Other  ENGLISH        WIDOWED    WHITE
# 1                    HOME  Medicaid  ENGLISH        WIDOWED    WHITE
# 2                 HOSPICE  Medicaid  ENGLISH        WIDOWED    WHITE
# 3                    HOME  Medicaid  ENGLISH        WIDOWED    WHITE
# 4                     NaN     Other  ENGLISH         SINGLE    WHITE
# ...                   ...       ...      ...            ...      ...
# 438168   HOME HEALTH CARE     Other  ENGLISH         SINGLE    WHITE
# 438169   HOME HEALTH CARE     Other  ENGLISH         SINGLE    WHITE
# 438170               DIED     Other  ENGLISH        WIDOWED    WHITE
# 438171               HOME     Other  ENGLISH        WIDOWED    WHITE
# 438172              REHAB     Other  ENGLISH            NaN  UNKNOWN
#
#            stay_id                      first_careunit  \
# 0              NaN                                 NaN
# 1              NaN                                 NaN
# 2              NaN                                 NaN
# 3       39553978.0  Medical Intensive Care Unit (MICU)
# 4              NaN                                 NaN
# ...            ...                                 ...
# 438168  36075953.0  Medical Intensive Care Unit (MICU)
# 438169         NaN                                 NaN
# 438170  38978960.0                 Trauma SICU (TSICU)
# 438171         NaN                                 NaN
# 438172  36195440.0                 Trauma SICU (TSICU)
#
#                               last_careunit           intime          outtime
# 0                                       NaN              NaN              NaN
# 1                                       NaN              NaN              NaN
# 2                                       NaN              NaN              NaN
# 3        Medical Intensive Care Unit (MICU)  7/23/2180 14:00  7/23/2180 23:50
# 4                                       NaN              NaN              NaN
# ...                                     ...              ...              ...
# 438168   Medical Intensive Care Unit (MICU)   1/8/2149 18:12  1/10/2149 13:11
# 438169                                  NaN              NaN              NaN
# 438170  Surgical Intensive Care Unit (SICU)   9/12/2164 9:26  9/17/2164 16:35
# 438171                                  NaN              NaN              NaN
# 438172                  Trauma SICU (TSICU)  11/2/2145 22:59  11/4/2145 21:29
#
# [438173 rows x 17 columns]

# %%
df3_serv=pd.read_csv('services.csv')
df3_serv
# Out:
#         subject_id   hadm_id     transfertime prev_service curr_service
# 0         10000032  22595853   5/6/2180 22:24          NaN          MED
# 1         10000032  22841357  6/26/2180 18:28          NaN          MED
# 2         10000032  25742920   8/5/2180 23:44          NaN          MED
# 3         10000032  29079034  7/23/2180 12:36          NaN          MED
# 4         10000068  25022803   3/3/2160 23:17          NaN          MED
# ...            ...       ...              ...          ...          ...
# 468024    19999828  29734428  7/18/2147 16:24          NaN         SURG
# 468025    19999840  21033226  9/10/2164 13:49          NaN         NMED
# 468026    19999840  21033226  9/14/2164 10:40         NMED          MED
# 468027    19999840  26071774   7/25/2164 0:27          NaN         NMED
# 468028    19999987  23865745  11/2/2145 21:39          NaN         NMED
#
# [468029 rows x 5 columns]

# %%
df3_serv=df3_serv.drop(columns=['transfertime','prev_service'], axis=1)
# Out:
#         subject_id   hadm_id curr_service
# 0         10000032  22595853          MED
# 1         10000032  22841357          MED
# 2         10000032  25742920          MED
# 3         10000032  29079034          MED
# 4         10000068  25022803          MED
# ...            ...       ...          ...
# 468024    19999828  29734428         SURG
# 468025    19999840  21033226         NMED
# 468026    19999840  21033226          MED
# 468027    19999840  26071774         NMED
# 468028    19999987  23865745         NMED
#
# [468029 rows x 3 columns]

# %%
df_merged_2 = df_merged.merge(df3_serv, how='outer')
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1         10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2         10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3         10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 4         10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...            ...       ...                  ...                  ...
# 480223    19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 480224    19999840  21033226  2164-09-10 13:47:00  2164-09-17 13:42:00
# 480225    19999840  21033226  2164-09-10 13:47:00  2164-09-17 13:42:00
# 480226    19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 480227    19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#                   deathtime  admission_type      admission_location  \
# 0                       NaN          URGENT  TRANSFER FROM HOSPITAL
# 1                       NaN        EW EMER.          EMERGENCY ROOM
# 2                       NaN        EW EMER.          EMERGENCY ROOM
# 3                       NaN        EW EMER.          EMERGENCY ROOM
# 4                       NaN  EU OBSERVATION          EMERGENCY ROOM
# ...                     ...             ...                     ...
# 480223                  NaN        EW EMER.      PHYSICIAN REFERRAL
# 480224  2164-09-17 13:42:00        EW EMER.          EMERGENCY ROOM
# 480225  2164-09-17 13:42:00        EW EMER.          EMERGENCY ROOM
# 480226                  NaN        EW EMER.          EMERGENCY ROOM
# 480227                  NaN        EW EMER.          EMERGENCY ROOM
#
#        discharge_location insurance language marital_status     race  \
# 0                    HOME     Other  ENGLISH        WIDOWED    WHITE
# 1                    HOME  Medicaid  ENGLISH        WIDOWED    WHITE
# 2                 HOSPICE  Medicaid  ENGLISH        WIDOWED    WHITE
# 3                    HOME  Medicaid  ENGLISH        WIDOWED    WHITE
# 4                     NaN     Other  ENGLISH         SINGLE    WHITE
# ...                   ...       ...      ...            ...      ...
# 480223   HOME HEALTH CARE     Other  ENGLISH         SINGLE    WHITE
# 480224               DIED     Other  ENGLISH        WIDOWED    WHITE
# 480225               DIED     Other  ENGLISH        WIDOWED    WHITE
# 480226               HOME     Other  ENGLISH        WIDOWED    WHITE
# 480227              REHAB     Other  ENGLISH            NaN  UNKNOWN
#
#            stay_id                      first_careunit  \
# 0              NaN                                 NaN
# 1              NaN                                 NaN
# 2              NaN                                 NaN
# 3       39553978.0  Medical Intensive Care Unit (MICU)
# 4              NaN                                 NaN
# ...            ...                                 ...
# 480223         NaN                                 NaN
# 480224  38978960.0                 Trauma SICU (TSICU)
# 480225  38978960.0                 Trauma SICU (TSICU)
# 480226         NaN                                 NaN
# 480227  36195440.0                 Trauma SICU (TSICU)
#
#                               last_careunit           intime          outtime  \
# 0                                       NaN              NaN              NaN
# 1                                       NaN              NaN              NaN
# 2                                       NaN              NaN              NaN
# 3        Medical Intensive Care Unit (MICU)  7/23/2180 14:00  7/23/2180 23:50
# 4                                       NaN              NaN              NaN
# ...                                     ...              ...              ...
# 480223                                  NaN              NaN              NaN
# 480224  Surgical Intensive Care Unit (SICU)   9/12/2164 9:26  9/17/2164 16:35
# 480225  Surgical Intensive Care Unit (SICU)   9/12/2164 9:26  9/17/2164 16:35
# 480226                                  NaN              NaN              NaN
# 480227                  Trauma SICU (TSICU)  11/2/2145 22:59  11/4/2145 21:29
#
#        curr_service
# 0               MED
# 1               MED
# 2               MED
# 3               MED
# 4               MED
# ...             ...
# 480223         SURG
# 480224         NMED
# 480225          MED
# 480226         NMED
# 480227         NMED
#
# [480228 rows x 18 columns]

# %%
df4_patient=pd.read_csv("patients.csv")
df4_patient
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0         10000032      F          52         2180       2014 - 2016
# 1         10000048      F          23         2126       2008 - 2010
# 2         10000068      F          19         2160       2008 - 2010
# 3         10000084      M          72         2160       2017 - 2019
# 4         10000102      F          27         2136       2008 - 2010
# ...            ...    ...         ...          ...               ...
# 299707    19999828      F          46         2147       2017 - 2019
# 299708    19999829      F          28         2186       2008 - 2010
# 299709    19999840      M          58         2164       2008 - 2010
# 299710    19999914      F          49         2158       2017 - 2019
# 299711    19999987      F          57         2145       2011 - 2013
#
#               dod
# 0        9/9/2180
# 1             NaN
# 2             NaN
# 3       2/13/2161
# 4             NaN
# ...           ...
# 299707        NaN
# 299708        NaN
# 299709  9/17/2164
# 299710        NaN
# 299711        NaN
#
# [299712 rows x 6 columns]

# %%
df4_patient=df4_patient.drop(columns=['anchor_year', 'dod'], axis=1)
# Out:
#         subject_id gender  anchor_age anchor_year_group
# 0         10000032      F          52       2014 - 2016
# 1         10000048      F          23       2008 - 2010
# 2         10000068      F          19       2008 - 2010
# 3         10000084      M          72       2017 - 2019
# 4         10000102      F          27       2008 - 2010
# ...            ...    ...         ...               ...
# 299707    19999828      F          46       2017 - 2019
# 299708    19999829      F          28       2008 - 2010
# 299709    19999840      M          58       2008 - 2010
# 299710    19999914      F          49       2017 - 2019
# 299711    19999987      F          57       2011 - 2013
#
# [299712 rows x 4 columns]

# %%
df_merged_3 = df_merged_2.merge(df4_patient, how='outer')
# Out:
#         subject_id     hadm_id            admittime            dischtime  \
# 0         10000032  22595853.0  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1         10000032  22841357.0  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2         10000032  25742920.0  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3         10000032  29079034.0  2180-07-23 12:35:00  2180-07-25 17:55:00
# 4         10000068  25022803.0  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...            ...         ...                  ...                  ...
# 599202    19999659         NaN                  NaN                  NaN
# 599203    19999750         NaN                  NaN                  NaN
# 599204    19999782         NaN                  NaN                  NaN
# 599205    19999829         NaN                  NaN                  NaN
# 599206    19999914         NaN                  NaN                  NaN
#
#        deathtime  admission_type      admission_location discharge_location  \
# 0            NaN          URGENT  TRANSFER FROM HOSPITAL               HOME
# 1            NaN        EW EMER.          EMERGENCY ROOM               HOME
# 2            NaN        EW EMER.          EMERGENCY ROOM            HOSPICE
# 3            NaN        EW EMER.          EMERGENCY ROOM               HOME
# 4            NaN  EU OBSERVATION          EMERGENCY ROOM                NaN
# ...          ...             ...                     ...                ...
# 599202       NaN             NaN                     NaN                NaN
# 599203       NaN             NaN                     NaN                NaN
# 599204       NaN             NaN                     NaN                NaN
# 599205       NaN             NaN                     NaN                NaN
# 599206       NaN             NaN                     NaN                NaN
#
#        insurance language  ...   race     stay_id  \
# 0          Other  ENGLISH  ...  WHITE         NaN
# 1       Medicaid  ENGLISH  ...  WHITE         NaN
# 2       Medicaid  ENGLISH  ...  WHITE         NaN
# 3       Medicaid  ENGLISH  ...  WHITE  39553978.0
# 4          Other  ENGLISH  ...  WHITE         NaN
# ...          ...      ...  ...    ...         ...
# 599202       NaN      NaN  ...    NaN         NaN
# 599203       NaN      NaN  ...    NaN         NaN
# 599204       NaN      NaN  ...    NaN         NaN
# 599205       NaN      NaN  ...    NaN         NaN
# 599206       NaN      NaN  ...    NaN         NaN
#
#                             first_careunit  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3       Medical Intensive Care Unit (MICU)
# 4                                      NaN
# ...                                    ...
# 599202                                 NaN
# 599203                                 NaN
# 599204                                 NaN
# 599205                                 NaN
# 599206                                 NaN
#
#                              last_careunit           intime          outtime  \
# 0                                      NaN              NaN              NaN
# 1                                      NaN              NaN              NaN
# 2                                      NaN              NaN              NaN
# 3       Medical Intensive Care Unit (MICU)  7/23/2180 14:00  7/23/2180 23:50
# 4                                      NaN              NaN              NaN
# ...                                    ...              ...              ...
# 599202                                 NaN              NaN              NaN
# 599203                                 NaN              NaN              NaN
# 599204                                 NaN              NaN              NaN
# 599205                                 NaN              NaN              NaN
# 599206                                 NaN              NaN              NaN
#
#        curr_service gender anchor_age  anchor_year_group
# 0               MED      F         52        2014 - 2016
# 1               MED      F         52        2014 - 2016
# 2               MED      F         52        2014 - 2016
# 3               MED      F         52        2014 - 2016
# 4               MED      F         19        2008 - 2010
# ...             ...    ...        ...                ...
# 599202          NaN      F         58        2011 - 2013
# 599203          NaN      M         45        2017 - 2019
# 599204          NaN      F         22        2008 - 2010
# 599205          NaN      F         28        2008 - 2010
# 599206          NaN      F         49        2017 - 2019
#
# [599207 rows x 21 columns]

# %%
df5_omr=pd.read_csv('omr.csv')
df5_omr
# Out:
#          subject_id   chartdate  seq_num      result_name result_value
# 0          10000032   4/27/2180        1   Blood Pressure       110/65
# 1          10000032   4/27/2180        1     Weight (Lbs)           94
# 2          10000032    5/7/2180        1      BMI (kg/m2)           18
# 3          10000032    5/7/2180        1  Height (Inches)           60
# 4          10000032    5/7/2180        1     Weight (Lbs)        92.15
# ...             ...         ...      ...              ...          ...
# 1048570    11654378  11/19/2203        1   Blood Pressure      144/105
# 1048571    11654378  11/19/2203        1      BMI (kg/m2)         33.9
# 1048572    11654378  11/19/2203        1     Weight (Lbs)        191.5
# 1048573    11654378  11/24/2203        1   Blood Pressure       142/97
# 1048574    11654378   2/12/2204        1   Blood Pressure       139/95
#
# [1048575 rows x 5 columns]

# %%
df5_omr=df5_omr.drop(columns=['chartdate','seq_num'], axis=1)
# Out:
#          subject_id      result_name result_value
# 0          10000032   Blood Pressure       110/65
# 1          10000032     Weight (Lbs)           94
# 2          10000032      BMI (kg/m2)           18
# 3          10000032  Height (Inches)           60
# 4          10000032     Weight (Lbs)        92.15
# ...             ...              ...          ...
# 1048570    11654378   Blood Pressure      144/105
# 1048571    11654378      BMI (kg/m2)         33.9
# 1048572    11654378     Weight (Lbs)        191.5
# 1048573    11654378   Blood Pressure       142/97
# 1048574    11654378   Blood Pressure       139/95
#
# [1048575 rows x 3 columns]

# %%
df5_omr_2=df5_omr[(df5_omr['result_name']=='Weight (Lbs)') | (df5_omr['result_name']=='BMI (kg/m2)')]
df5_omr_2['result_value'] = df5_omr_2['result_value'].astype(float)
# Out:
#          subject_id   result_name result_value
# 1          10000032  Weight (Lbs)           94
# 2          10000032   BMI (kg/m2)           18
# 4          10000032  Weight (Lbs)        92.15
# 5          10000032  Weight (Lbs)        92.15
# 6          10000032  Weight (Lbs)        92.15
# ...             ...           ...          ...
# 1048566    11654378  Weight (Lbs)          189
# 1048568    11654378   BMI (kg/m2)         33.8
# 1048569    11654378  Weight (Lbs)        190.9
# 1048571    11654378   BMI (kg/m2)         33.9
# 1048572    11654378  Weight (Lbs)        191.5
#
# [579367 rows x 3 columns]

# %%
averages = df5_omr_2.groupby(['result_name', 'subject_id'])['result_value'].mean()
averages_df = averages.reset_index()
averages_pivot = averages_df.pivot(index='subject_id', columns='result_name', values='result_value')
averages_pivot.reset_index(inplace=True)
# Out:
# result_name   subject_id
# BMI (kg/m2)   10000032       18.537500
#               10000084       24.400000
#               10000117       18.548000
#               10000248       25.500000
#               10000635       33.985714
#                                ...
# Weight (Lbs)  11654293      150.000000
#               11654306      286.733333
#               11654310      347.000000
#               11654368      115.400000
#               11654378      184.133962
# Name: result_value, Length: 47232, dtype: float64

# %%
averages_pivot=averages_pivot[(averages_pivot['BMI (kg/m2)']<=100) & (averages_pivot['Weight (Lbs)']<=300)]
# Out:
# result_name  subject_id  BMI (kg/m2)  Weight (Lbs)
# 0              10000032    18.537500     93.104000
# 1              10000084    24.400000    170.000000
# 2              10000117    18.548000    111.129643
# 3              10000248    25.500000    168.000000
# 6              10000635    33.985714    215.871429
# ...                 ...          ...           ...
# 24613          11654285    36.989362    243.544043
# 24614          11654293    28.333333    150.000000
# 24615          11654306    41.933333    286.733333
# 24617          11654368    20.800000    115.400000
# 24618          11654378    32.460377    184.133962
#
# [22196 rows x 3 columns]

# %%
df_merged_4=df_merged_3.merge(averages_pivot, how='outer')
# Out:
#         subject_id     hadm_id            admittime            dischtime  \
# 0         10000032  22595853.0  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1         10000032  22841357.0  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2         10000032  25742920.0  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3         10000032  29079034.0  2180-07-23 12:35:00  2180-07-25 17:55:00
# 4         10000068  25022803.0  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...            ...         ...                  ...                  ...
# 599202    19999659         NaN                  NaN                  NaN
# 599203    19999750         NaN                  NaN                  NaN
# 599204    19999782         NaN                  NaN                  NaN
# 599205    19999829         NaN                  NaN                  NaN
# 599206    19999914         NaN                  NaN                  NaN
#
#        deathtime  admission_type      admission_location discharge_location  \
# 0            NaN          URGENT  TRANSFER FROM HOSPITAL               HOME
# 1            NaN        EW EMER.          EMERGENCY ROOM               HOME
# 2            NaN        EW EMER.          EMERGENCY ROOM            HOSPICE
# 3            NaN        EW EMER.          EMERGENCY ROOM               HOME
# 4            NaN  EU OBSERVATION          EMERGENCY ROOM                NaN
# ...          ...             ...                     ...                ...
# 599202       NaN             NaN                     NaN                NaN
# 599203       NaN             NaN                     NaN                NaN
# 599204       NaN             NaN                     NaN                NaN
# 599205       NaN             NaN                     NaN                NaN
# 599206       NaN             NaN                     NaN                NaN
#
#        insurance language  ...                      first_careunit  \
# 0          Other  ENGLISH  ...                                 NaN
# 1       Medicaid  ENGLISH  ...                                 NaN
# 2       Medicaid  ENGLISH  ...                                 NaN
# 3       Medicaid  ENGLISH  ...  Medical Intensive Care Unit (MICU)
# 4          Other  ENGLISH  ...                                 NaN
# ...          ...      ...  ...                                 ...
# 599202       NaN      NaN  ...                                 NaN
# 599203       NaN      NaN  ...                                 NaN
# 599204       NaN      NaN  ...                                 NaN
# 599205       NaN      NaN  ...                                 NaN
# 599206       NaN      NaN  ...                                 NaN
#
#                              last_careunit           intime          outtime  \
# 0                                      NaN              NaN              NaN
# 1                                      NaN              NaN              NaN
# 2                                      NaN              NaN              NaN
# 3       Medical Intensive Care Unit (MICU)  7/23/2180 14:00  7/23/2180 23:50
# 4                                      NaN              NaN              NaN
# ...                                    ...              ...              ...
# 599202                                 NaN              NaN              NaN
# 599203                                 NaN              NaN              NaN
# 599204                                 NaN              NaN              NaN
# 599205                                 NaN              NaN              NaN
# 599206                                 NaN              NaN              NaN
#
#        curr_service gender anchor_age anchor_year_group BMI (kg/m2)  \
# 0               MED      F         52       2014 - 2016     18.5375
# 1               MED      F         52       2014 - 2016     18.5375
# 2               MED      F         52       2014 - 2016     18.5375
# 3               MED      F         52       2014 - 2016     18.5375
# 4               MED      F         19       2008 - 2010         NaN
# ...             ...    ...        ...               ...         ...
# 599202          NaN      F         58       2011 - 2013         NaN
# 599203          NaN      M         45       2017 - 2019         NaN
# 599204          NaN      F         22       2008 - 2010         NaN
# 599205          NaN      F         28       2008 - 2010         NaN
# 599206          NaN      F         49       2017 - 2019         NaN
#
#         Weight (Lbs)
# 0             93.104
# 1             93.104
# 2             93.104
# 3             93.104
# 4                NaN
# ...              ...
# 599202           NaN
# 599203           NaN
# 599204           NaN
# 599205           NaN
# 599206           NaN
#
# [599207 rows x 23 columns]

# %%
df_merged_final=df_merged_4.dropna(subset=['hadm_id', 'Weight (Lbs)'])
df_merged_final
# Out:
#        subject_id     hadm_id            admittime            dischtime  \
# 0        10000032  22595853.0  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1        10000032  22841357.0  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2        10000032  25742920.0  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3        10000032  29079034.0  2180-07-23 12:35:00  2180-07-25 17:55:00
# 5        10000084  23052089.0  2160-11-21 01:56:00  2160-11-25 14:52:00
# ...           ...         ...                  ...                  ...
# 78757    11654368  23643805.0  2129-09-10 04:02:00  2129-09-12 11:45:00
# 78758    11654378  24176611.0  2198-09-14 13:09:00  2198-09-16 15:53:00
# 78759    11654378  28760789.0  2203-01-13 04:23:00  2203-01-18 13:00:00
# 78760    11654378  29542546.0  2201-03-29 07:15:00  2201-03-29 20:45:00
# 78761    11654378  29893525.0  2199-09-13 21:57:00  2199-09-15 16:45:00
#
#       deathtime               admission_type      admission_location  \
# 0           NaN                       URGENT  TRANSFER FROM HOSPITAL
# 1           NaN                     EW EMER.          EMERGENCY ROOM
# 2           NaN                     EW EMER.          EMERGENCY ROOM
# 3           NaN                     EW EMER.          EMERGENCY ROOM
# 5           NaN                     EW EMER.   WALK-IN/SELF REFERRAL
# ...         ...                          ...                     ...
# 78757       NaN                       URGENT      PHYSICIAN REFERRAL
# 78758       NaN                     EW EMER.          EMERGENCY ROOM
# 78759       NaN                     EW EMER.          EMERGENCY ROOM
# 78760       NaN  SURGICAL SAME DAY ADMISSION      PHYSICIAN REFERRAL
# 78761       NaN                       URGENT  TRANSFER FROM HOSPITAL
#
#       discharge_location insurance language  ...  \
# 0                   HOME     Other  ENGLISH  ...
# 1                   HOME  Medicaid  ENGLISH  ...
# 2                HOSPICE  Medicaid  ENGLISH  ...
# 3                   HOME  Medicaid  ENGLISH  ...
# 5       HOME HEALTH CARE  Medicare  ENGLISH  ...
# ...                  ...       ...      ...  ...
# 78757               HOME     Other  ENGLISH  ...
# 78758               HOME  Medicare  ENGLISH  ...
# 78759               HOME  Medicare  ENGLISH  ...
# 78760               HOME  Medicare  ENGLISH  ...
# 78761   HOME HEALTH CARE  Medicare  ENGLISH  ...
#
#                            first_careunit                       last_careunit  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3      Medical Intensive Care Unit (MICU)  Medical Intensive Care Unit (MICU)
# 5                                     NaN                                 NaN
# ...                                   ...                                 ...
# 78757                                 NaN                                 NaN
# 78758                                 NaN                                 NaN
# 78759                                 NaN                                 NaN
# 78760                                 NaN                                 NaN
# 78761                                 NaN                                 NaN
#
#                 intime          outtime curr_service gender anchor_age  \
# 0                  NaN              NaN          MED      F         52
# 1                  NaN              NaN          MED      F         52
# 2                  NaN              NaN          MED      F         52
# 3      7/23/2180 14:00  7/23/2180 23:50          MED      F         52
# 5                  NaN              NaN          MED      M         72
# ...                ...              ...          ...    ...        ...
# 78757              NaN              NaN          OBS      F         31
# 78758              NaN              NaN          MED      F         46
# 78759              NaN              NaN         SURG      F         46
# 78760              NaN              NaN        ORTHO      F         46
# 78761              NaN              NaN        NSURG      F         46
#
#       anchor_year_group BMI (kg/m2)  Weight (Lbs)
# 0           2014 - 2016   18.537500     93.104000
# 1           2014 - 2016   18.537500     93.104000
# 2           2014 - 2016   18.537500     93.104000
# 3           2014 - 2016   18.537500     93.104000
# 5           2017 - 2019   24.400000    170.000000
# ...                 ...         ...           ...
# 78757       2011 - 2013   20.800000    115.400000
# 78758       2008 - 2010   32.460377    184.133962
# 78759       2008 - 2010   32.460377    184.133962
# 78760       2008 - 2010   32.460377    184.133962
# 78761       2008 - 2010   32.460377    184.133962
#
# [56743 rows x 23 columns]

# %%
df_merged_final=df_merged_final[df_merged_final['deathtime'].isna()]
# Out:
#        subject_id     hadm_id            admittime            dischtime  \
# 0        10000032  22595853.0  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1        10000032  22841357.0  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2        10000032  25742920.0  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3        10000032  29079034.0  2180-07-23 12:35:00  2180-07-25 17:55:00
# 5        10000084  23052089.0  2160-11-21 01:56:00  2160-11-25 14:52:00
# ...           ...         ...                  ...                  ...
# 78757    11654368  23643805.0  2129-09-10 04:02:00  2129-09-12 11:45:00
# 78758    11654378  24176611.0  2198-09-14 13:09:00  2198-09-16 15:53:00
# 78759    11654378  28760789.0  2203-01-13 04:23:00  2203-01-18 13:00:00
# 78760    11654378  29542546.0  2201-03-29 07:15:00  2201-03-29 20:45:00
# 78761    11654378  29893525.0  2199-09-13 21:57:00  2199-09-15 16:45:00
#
#       deathtime               admission_type      admission_location  \
# 0           NaN                       URGENT  TRANSFER FROM HOSPITAL
# 1           NaN                     EW EMER.          EMERGENCY ROOM
# 2           NaN                     EW EMER.          EMERGENCY ROOM
# 3           NaN                     EW EMER.          EMERGENCY ROOM
# 5           NaN                     EW EMER.   WALK-IN/SELF REFERRAL
# ...         ...                          ...                     ...
# 78757       NaN                       URGENT      PHYSICIAN REFERRAL
# 78758       NaN                     EW EMER.          EMERGENCY ROOM
# 78759       NaN                     EW EMER.          EMERGENCY ROOM
# 78760       NaN  SURGICAL SAME DAY ADMISSION      PHYSICIAN REFERRAL
# 78761       NaN                       URGENT  TRANSFER FROM HOSPITAL
#
#       discharge_location insurance language  ...  \
# 0                   HOME     Other  ENGLISH  ...
# 1                   HOME  Medicaid  ENGLISH  ...
# 2                HOSPICE  Medicaid  ENGLISH  ...
# 3                   HOME  Medicaid  ENGLISH  ...
# 5       HOME HEALTH CARE  Medicare  ENGLISH  ...
# ...                  ...       ...      ...  ...
# 78757               HOME     Other  ENGLISH  ...
# 78758               HOME  Medicare  ENGLISH  ...
# 78759               HOME  Medicare  ENGLISH  ...
# 78760               HOME  Medicare  ENGLISH  ...
# 78761   HOME HEALTH CARE  Medicare  ENGLISH  ...
#
#                            first_careunit                       last_careunit  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3      Medical Intensive Care Unit (MICU)  Medical Intensive Care Unit (MICU)
# 5                                     NaN                                 NaN
# ...                                   ...                                 ...
# 78757                                 NaN                                 NaN
# 78758                                 NaN                                 NaN
# 78759                                 NaN                                 NaN
# 78760                                 NaN                                 NaN
# 78761                                 NaN                                 NaN
#
#                 intime          outtime curr_service gender anchor_age  \
# 0                  NaN              NaN          MED      F         52
# 1                  NaN              NaN          MED      F         52
# 2                  NaN              NaN          MED      F         52
# 3      7/23/2180 14:00  7/23/2180 23:50          MED      F         52
# 5                  NaN              NaN          MED      M         72
# ...                ...              ...          ...    ...        ...
# 78757              NaN              NaN          OBS      F         31
# 78758              NaN              NaN          MED      F         46
# 78759              NaN              NaN         SURG      F         46
# 78760              NaN              NaN        ORTHO      F         46
# 78761              NaN              NaN        NSURG      F         46
#
#       anchor_year_group BMI (kg/m2)  Weight (Lbs)
# 0           2014 - 2016   18.537500     93.104000
# 1           2014 - 2016   18.537500     93.104000
# 2           2014 - 2016   18.537500     93.104000
# 3           2014 - 2016   18.537500     93.104000
# 5           2017 - 2019   24.400000    170.000000
# ...                 ...         ...           ...
# 78757       2011 - 2013   20.800000    115.400000
# 78758       2008 - 2010   32.460377    184.133962
# 78759       2008 - 2010   32.460377    184.133962
# 78760       2008 - 2010   32.460377    184.133962
# 78761       2008 - 2010   32.460377    184.133962
#
# [55573 rows x 23 columns]

# %%
df_merged_final['Inpatient_Flow']=np.zeros(len(df_merged_final))
for i in lst:
  if pd.isna(df_merged_final['intime'][i])==True:
    df_merged_final['Inpatient_Flow'][i]=0
  else:
    df_merged_final['Inpatient_Flow'][i]=1
# Out:
# <ipython-input-26-2a1251d3bd49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merged_final['Inpatient_Flow']=np.zeros(len(df_merged_final))
# <ipython-input-26-2a1251d3bd49>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merged_final['Inpatient_Flow'][i]=0
# <ipython-input-26-2a1251d3bd49>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merged_final['Inpatient_Flow'][i]=1

# %%
df_merged_final['Inpatient_Flow']=df_merged_final['Inpatient_Flow'].astype(int)
# Out:
# <ipython-input-27-62ecc099725f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merged_final['Inpatient_Flow']=df_merged_final['Inpatient_Flow'].astype(int)
#        subject_id     hadm_id            admittime            dischtime  \
# 0        10000032  22595853.0  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1        10000032  22841357.0  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2        10000032  25742920.0  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3        10000032  29079034.0  2180-07-23 12:35:00  2180-07-25 17:55:00
# 5        10000084  23052089.0  2160-11-21 01:56:00  2160-11-25 14:52:00
# ...           ...         ...                  ...                  ...
# 78757    11654368  23643805.0  2129-09-10 04:02:00  2129-09-12 11:45:00
# 78758    11654378  24176611.0  2198-09-14 13:09:00  2198-09-16 15:53:00
# 78759    11654378  28760789.0  2203-01-13 04:23:00  2203-01-18 13:00:00
# 78760    11654378  29542546.0  2201-03-29 07:15:00  2201-03-29 20:45:00
# 78761    11654378  29893525.0  2199-09-13 21:57:00  2199-09-15 16:45:00
#
#       deathtime               admission_type      admission_location  \
# 0           NaN                       URGENT  TRANSFER FROM HOSPITAL
# 1           NaN                     EW EMER.          EMERGENCY ROOM
# 2           NaN                     EW EMER.          EMERGENCY ROOM
# 3           NaN                     EW EMER.          EMERGENCY ROOM
# 5           NaN                     EW EMER.   WALK-IN/SELF REFERRAL
# ...         ...                          ...                     ...
# 78757       NaN                       URGENT      PHYSICIAN REFERRAL
# 78758       NaN                     EW EMER.          EMERGENCY ROOM
# 78759       NaN                     EW EMER.          EMERGENCY ROOM
# 78760       NaN  SURGICAL SAME DAY ADMISSION      PHYSICIAN REFERRAL
# 78761       NaN                       URGENT  TRANSFER FROM HOSPITAL
#
#       discharge_location insurance language  ...  \
# 0                   HOME     Other  ENGLISH  ...
# 1                   HOME  Medicaid  ENGLISH  ...
# 2                HOSPICE  Medicaid  ENGLISH  ...
# 3                   HOME  Medicaid  ENGLISH  ...
# 5       HOME HEALTH CARE  Medicare  ENGLISH  ...
# ...                  ...       ...      ...  ...
# 78757               HOME     Other  ENGLISH  ...
# 78758               HOME  Medicare  ENGLISH  ...
# 78759               HOME  Medicare  ENGLISH  ...
# 78760               HOME  Medicare  ENGLISH  ...
# 78761   HOME HEALTH CARE  Medicare  ENGLISH  ...
#
#                             last_careunit           intime          outtime  \
# 0                                     NaN              NaN              NaN
# 1                                     NaN              NaN              NaN
# 2                                     NaN              NaN              NaN
# 3      Medical Intensive Care Unit (MICU)  7/23/2180 14:00  7/23/2180 23:50
# 5                                     NaN              NaN              NaN
# ...                                   ...              ...              ...
# 78757                                 NaN              NaN              NaN
# 78758                                 NaN              NaN              NaN
# 78759                                 NaN              NaN              NaN
# 78760                                 NaN              NaN              NaN
# 78761                                 NaN              NaN              NaN
#
#       curr_service gender anchor_age anchor_year_group BMI (kg/m2)  \
# 0              MED      F         52       2014 - 2016   18.537500
# 1              MED      F         52       2014 - 2016   18.537500
# 2              MED      F         52       2014 - 2016   18.537500
# 3              MED      F         52       2014 - 2016   18.537500
# 5              MED      M         72       2017 - 2019   24.400000
# ...            ...    ...        ...               ...         ...
# 78757          OBS      F         31       2011 - 2013   20.800000
# 78758          MED      F         46       2008 - 2010   32.460377
# 78759         SURG      F         46       2008 - 2010   32.460377
# 78760        ORTHO      F         46       2008 - 2010   32.460377
# 78761        NSURG      F         46       2008 - 2010   32.460377
#
#       Weight (Lbs)  Inpatient_Flow
# 0        93.104000               0
# 1        93.104000               0
# 2        93.104000               0
# 3        93.104000               1
# 5       170.000000               0
# ...            ...             ...
# 78757   115.400000               0
# 78758   184.133962               0
# 78759   184.133962               0
# 78760   184.133962               0
# 78761   184.133962               0
#
# [55573 rows x 24 columns]

# %%
df_merged_final=df_merged_final.drop(columns=['deathtime','stay_id','intime', 'outtime'])
# Out:
#        subject_id     hadm_id            admittime            dischtime  \
# 0        10000032  22595853.0  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1        10000032  22841357.0  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2        10000032  25742920.0  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3        10000032  29079034.0  2180-07-23 12:35:00  2180-07-25 17:55:00
# 5        10000084  23052089.0  2160-11-21 01:56:00  2160-11-25 14:52:00
# ...           ...         ...                  ...                  ...
# 78757    11654368  23643805.0  2129-09-10 04:02:00  2129-09-12 11:45:00
# 78758    11654378  24176611.0  2198-09-14 13:09:00  2198-09-16 15:53:00
# 78759    11654378  28760789.0  2203-01-13 04:23:00  2203-01-18 13:00:00
# 78760    11654378  29542546.0  2201-03-29 07:15:00  2201-03-29 20:45:00
# 78761    11654378  29893525.0  2199-09-13 21:57:00  2199-09-15 16:45:00
#
#                     admission_type      admission_location discharge_location  \
# 0                           URGENT  TRANSFER FROM HOSPITAL               HOME
# 1                         EW EMER.          EMERGENCY ROOM               HOME
# 2                         EW EMER.          EMERGENCY ROOM            HOSPICE
# 3                         EW EMER.          EMERGENCY ROOM               HOME
# 5                         EW EMER.   WALK-IN/SELF REFERRAL   HOME HEALTH CARE
# ...                            ...                     ...                ...
# 78757                       URGENT      PHYSICIAN REFERRAL               HOME
# 78758                     EW EMER.          EMERGENCY ROOM               HOME
# 78759                     EW EMER.          EMERGENCY ROOM               HOME
# 78760  SURGICAL SAME DAY ADMISSION      PHYSICIAN REFERRAL               HOME
# 78761                       URGENT  TRANSFER FROM HOSPITAL   HOME HEALTH CARE
#
#       insurance language marital_status   race  \
# 0         Other  ENGLISH        WIDOWED  WHITE
# 1      Medicaid  ENGLISH        WIDOWED  WHITE
# 2      Medicaid  ENGLISH        WIDOWED  WHITE
# 3      Medicaid  ENGLISH        WIDOWED  WHITE
# 5      Medicare  ENGLISH        MARRIED  WHITE
# ...         ...      ...            ...    ...
# 78757     Other  ENGLISH        MARRIED  WHITE
# 78758  Medicare  ENGLISH       DIVORCED  WHITE
# 78759  Medicare  ENGLISH       DIVORCED  WHITE
# 78760  Medicare  ENGLISH       DIVORCED  WHITE
# 78761  Medicare  ENGLISH       DIVORCED  WHITE
#
#                            first_careunit                       last_careunit  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3      Medical Intensive Care Unit (MICU)  Medical Intensive Care Unit (MICU)
# 5                                     NaN                                 NaN
# ...                                   ...                                 ...
# 78757                                 NaN                                 NaN
# 78758                                 NaN                                 NaN
# 78759                                 NaN                                 NaN
# 78760                                 NaN                                 NaN
# 78761                                 NaN                                 NaN
#
#       curr_service gender  anchor_age anchor_year_group  BMI (kg/m2)  \
# 0              MED      F          52       2014 - 2016    18.537500
# 1              MED      F          52       2014 - 2016    18.537500
# 2              MED      F          52       2014 - 2016    18.537500
# 3              MED      F          52       2014 - 2016    18.537500
# 5              MED      M          72       2017 - 2019    24.400000
# ...            ...    ...         ...               ...          ...
# 78757          OBS      F          31       2011 - 2013    20.800000
# 78758          MED      F          46       2008 - 2010    32.460377
# 78759         SURG      F          46       2008 - 2010    32.460377
# 78760        ORTHO      F          46       2008 - 2010    32.460377
# 78761        NSURG      F          46       2008 - 2010    32.460377
#
#        Weight (Lbs)  Inpatient_Flow
# 0         93.104000               0
# 1         93.104000               0
# 2         93.104000               0
# 3         93.104000               1
# 5        170.000000               0
# ...             ...             ...
# 78757    115.400000               0
# 78758    184.133962               0
# 78759    184.133962               0
# 78760    184.133962               0
# 78761    184.133962               0
#
# [55573 rows x 20 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df_merged_final['admission_type'] = labelencoder.fit_transform(df_merged_final['admission_type'])
df_merged_final['admission_location'] = labelencoder.fit_transform(df_merged_final['admission_location'])
df_merged_final['discharge_location'] = labelencoder.fit_transform(df_merged_final['discharge_location'])
df_merged_final['insurance'] = labelencoder.fit_transform(df_merged_final['insurance'])
df_merged_final['language'] = labelencoder.fit_transform(df_merged_final['language'])
df_merged_final['marital_status'] = labelencoder.fit_transform(df_merged_final['marital_status'])
df_merged_final['race'] = labelencoder.fit_transform(df_merged_final['race'])
df_merged_final['curr_service'] = labelencoder.fit_transform(df_merged_final['curr_service'])
df_merged_final['gender'] = labelencoder.fit_transform(df_merged_final['gender'])
df_merged_final['anchor_year_group'] = labelencoder.fit_transform(df_merged_final['anchor_year_group'])
df_merged_final['first_careunit']= labelencoder.fit_transform(df_merged_final['first_careunit'])
df_merged_final['last_careunit']= labelencoder.fit_transform(df_merged_final['last_careunit'])
df_merged_final
# Out:
#        subject_id     hadm_id            admittime            dischtime  \
# 0        10000032  22595853.0  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1        10000032  22841357.0  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2        10000032  25742920.0  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3        10000032  29079034.0  2180-07-23 12:35:00  2180-07-25 17:55:00
# 5        10000084  23052089.0  2160-11-21 01:56:00  2160-11-25 14:52:00
# ...           ...         ...                  ...                  ...
# 78757    11654368  23643805.0  2129-09-10 04:02:00  2129-09-12 11:45:00
# 78758    11654378  24176611.0  2198-09-14 13:09:00  2198-09-16 15:53:00
# 78759    11654378  28760789.0  2203-01-13 04:23:00  2203-01-18 13:00:00
# 78760    11654378  29542546.0  2201-03-29 07:15:00  2201-03-29 20:45:00
# 78761    11654378  29893525.0  2199-09-13 21:57:00  2199-09-15 16:45:00
#
#        admission_type  admission_location  discharge_location  insurance  \
# 0                   8                   8                   6          2
# 1                   5                   2                   6          0
# 2                   5                   2                   8          0
# 3                   5                   2                   6          0
# 5                   5                  10                   7          1
# ...               ...                 ...                 ...        ...
# 78757               8                   6                   6          2
# 78758               5                   2                   6          1
# 78759               5                   2                   6          1
# 78760               7                   6                   6          1
# 78761               8                   8                   7          1
#
#        language  marital_status  race  first_careunit  last_careunit  \
# 0             1               3    28               9              9
# 1             1               3    28               9              9
# 2             1               3    28               9              9
# 3             1               3    28               2              2
# 5             1               1    28               9              9
# ...         ...             ...   ...             ...            ...
# 78757         1               1    28               9              9
# 78758         1               0    28               9              9
# 78759         1               0    28               9              9
# 78760         1               0    28               9              9
# 78761         1               0    28               9              9
#
#        curr_service  gender  anchor_age  anchor_year_group  BMI (kg/m2)  \
# 0                 7       0          52                  2    18.537500
# 1                 7       0          52                  2    18.537500
# 2                 7       0          52                  2    18.537500
# 3                 7       0          52                  2    18.537500
# 5                 7       1          72                  3    24.400000
# ...             ...     ...         ...                ...          ...
# 78757            10       0          31                  1    20.800000
# 78758             7       0          46                  0    32.460377
# 78759            15       0          46                  0    32.460377
# 78760            12       0          46                  0    32.460377
# 78761             9       0          46                  0    32.460377
#
#        Weight (Lbs)  Inpatient_Flow
# 0         93.104000               0
# 1         93.104000               0
# 2         93.104000               0
# 3         93.104000               1
# 5        170.000000               0
# ...             ...             ...
# 78757    115.400000               0
# 78758    184.133962               0
# 78759    184.133962               0
# 78760    184.133962               0
# 78761    184.133962               0
#
# [55573 rows x 20 columns]

# %%
from datetime import datetime
after_icu_begin=[datetime.strptime(value, "%Y-%m-%d %H:%M:%S") for value in df_merged_final['admittime']]
after_icu_begin
after_icu_end=[datetime.strptime(value, "%Y-%m-%d %H:%M:%S") for value in df_merged_final['dischtime']]
after_icu_end
los = []
for item1, item2 in zip(after_icu_end, after_icu_begin):
    duration = item1- item2
    duration_in_s = duration.total_seconds()
    los.append(duration_in_s/86400.00)
#after_icu_end=[datetime.fromisoformat(df_merged_icu['dischtime'][i]).timestamp() for i in range(0,len(df_merged_icu),1)]

# %%
fig, ax = plt.subplots()
sns.histplot(los, cbar_ax=ax)
ax.set_xlim(1, 100)
plt.xlabel("Length of stay in hospital")
plt.show()

# %%
df_merged_final['los']=los
df_merged_final
# Out:
#        subject_id     hadm_id            admittime            dischtime  \
# 0        10000032  22595853.0  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1        10000032  22841357.0  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2        10000032  25742920.0  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3        10000032  29079034.0  2180-07-23 12:35:00  2180-07-25 17:55:00
# 5        10000084  23052089.0  2160-11-21 01:56:00  2160-11-25 14:52:00
# ...           ...         ...                  ...                  ...
# 78757    11654368  23643805.0  2129-09-10 04:02:00  2129-09-12 11:45:00
# 78758    11654378  24176611.0  2198-09-14 13:09:00  2198-09-16 15:53:00
# 78759    11654378  28760789.0  2203-01-13 04:23:00  2203-01-18 13:00:00
# 78760    11654378  29542546.0  2201-03-29 07:15:00  2201-03-29 20:45:00
# 78761    11654378  29893525.0  2199-09-13 21:57:00  2199-09-15 16:45:00
#
#        admission_type  admission_location  discharge_location  insurance  \
# 0                   8                   8                   6          2
# 1                   5                   2                   6          0
# 2                   5                   2                   8          0
# 3                   5                   2                   6          0
# 5                   5                  10                   7          1
# ...               ...                 ...                 ...        ...
# 78757               8                   6                   6          2
# 78758               5                   2                   6          1
# 78759               5                   2                   6          1
# 78760               7                   6                   6          1
# 78761               8                   8                   7          1
#
#        language  marital_status  ...  first_careunit  last_careunit  \
# 0             1               3  ...               9              9
# 1             1               3  ...               9              9
# 2             1               3  ...               9              9
# 3             1               3  ...               2              2
# 5             1               1  ...               9              9
# ...         ...             ...  ...             ...            ...
# 78757         1               1  ...               9              9
# 78758         1               0  ...               9              9
# 78759         1               0  ...               9              9
# 78760         1               0  ...               9              9
# 78761         1               0  ...               9              9
#
#        curr_service  gender  anchor_age  anchor_year_group  BMI (kg/m2)  \
# 0                 7       0          52                  2    18.537500
# 1                 7       0          52                  2    18.537500
# 2                 7       0          52                  2    18.537500
# 3                 7       0          52                  2    18.537500
# 5                 7       1          72                  3    24.400000
# ...             ...     ...         ...                ...          ...
# 78757            10       0          31                  1    20.800000
# 78758             7       0          46                  0    32.460377
# 78759            15       0          46                  0    32.460377
# 78760            12       0          46                  0    32.460377
# 78761             9       0          46                  0    32.460377
#
#        Weight (Lbs)  Inpatient_Flow       los
# 0         93.104000               0  0.786111
# 1         93.104000               0  1.015278
# 2         93.104000               0  1.754167
# 3         93.104000               1  2.222222
# 5        170.000000               0  4.538889
# ...             ...             ...       ...
# 78757    115.400000               0  2.321528
# 78758    184.133962               0  2.113889
# 78759    184.133962               0  5.359028
# 78760    184.133962               0  0.562500
# 78761    184.133962               0  1.783333
#
# [55573 rows x 21 columns]

# %%
percentile_85 = np.percentile(df_merged_final.los, 85)

print("85th percentile:", percentile_85)
# Out:
# 85th percentile: 8.842361111111112

# %%
df_merged_final=df_merged_final[df_merged_final['los']<9]
df_merged_final
# Out:
#        subject_id     hadm_id            admittime            dischtime  \
# 0        10000032  22595853.0  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1        10000032  22841357.0  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2        10000032  25742920.0  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3        10000032  29079034.0  2180-07-23 12:35:00  2180-07-25 17:55:00
# 5        10000084  23052089.0  2160-11-21 01:56:00  2160-11-25 14:52:00
# ...           ...         ...                  ...                  ...
# 78757    11654368  23643805.0  2129-09-10 04:02:00  2129-09-12 11:45:00
# 78758    11654378  24176611.0  2198-09-14 13:09:00  2198-09-16 15:53:00
# 78759    11654378  28760789.0  2203-01-13 04:23:00  2203-01-18 13:00:00
# 78760    11654378  29542546.0  2201-03-29 07:15:00  2201-03-29 20:45:00
# 78761    11654378  29893525.0  2199-09-13 21:57:00  2199-09-15 16:45:00
#
#        admission_type  admission_location  discharge_location  insurance  \
# 0                   8                   8                   6          2
# 1                   5                   2                   6          0
# 2                   5                   2                   8          0
# 3                   5                   2                   6          0
# 5                   5                  10                   7          1
# ...               ...                 ...                 ...        ...
# 78757               8                   6                   6          2
# 78758               5                   2                   6          1
# 78759               5                   2                   6          1
# 78760               7                   6                   6          1
# 78761               8                   8                   7          1
#
#        language  marital_status  ...  first_careunit  last_careunit  \
# 0             1               3  ...               9              9
# 1             1               3  ...               9              9
# 2             1               3  ...               9              9
# 3             1               3  ...               2              2
# 5             1               1  ...               9              9
# ...         ...             ...  ...             ...            ...
# 78757         1               1  ...               9              9
# 78758         1               0  ...               9              9
# 78759         1               0  ...               9              9
# 78760         1               0  ...               9              9
# 78761         1               0  ...               9              9
#
#        curr_service  gender  anchor_age  anchor_year_group  BMI (kg/m2)  \
# 0                 7       0          52                  2    18.537500
# 1                 7       0          52                  2    18.537500
# 2                 7       0          52                  2    18.537500
# 3                 7       0          52                  2    18.537500
# 5                 7       1          72                  3    24.400000
# ...             ...     ...         ...                ...          ...
# 78757            10       0          31                  1    20.800000
# 78758             7       0          46                  0    32.460377
# 78759            15       0          46                  0    32.460377
# 78760            12       0          46                  0    32.460377
# 78761             9       0          46                  0    32.460377
#
#        Weight (Lbs)  Inpatient_Flow       los
# 0         93.104000               0  0.786111
# 1         93.104000               0  1.015278
# 2         93.104000               0  1.754167
# 3         93.104000               1  2.222222
# 5        170.000000               0  4.538889
# ...             ...             ...       ...
# 78757    115.400000               0  2.321528
# 78758    184.133962               0  2.113889
# 78759    184.133962               0  5.359028
# 78760    184.133962               0  0.562500
# 78761    184.133962               0  1.783333
#
# [47555 rows x 21 columns]

# %%
na_df=df_merged_final.isna().sum()
na_df
# Out:
# subject_id            0
# hadm_id               0
# admittime             0
# dischtime             0
# admission_type        0
# admission_location    0
# discharge_location    0
# insurance             0
# language              0
# marital_status        0
# race                  0
# first_careunit        0
# last_careunit         0
# curr_service          0
# gender                0
# anchor_age            0
# anchor_year_group     0
# BMI (kg/m2)           0
# Weight (Lbs)          0
# Inpatient_Flow        0
# los                   0
# dtype: int64

# %%
X=df_merged_final.iloc[:,4:].drop(columns=['Inpatient_Flow', 'los'])
X
# Out:
#        admission_type  admission_location  discharge_location  insurance  \
# 0                   8                   8                   6          2
# 1                   5                   2                   6          0
# 2                   5                   2                   8          0
# 3                   5                   2                   6          0
# 5                   5                  10                   7          1
# ...               ...                 ...                 ...        ...
# 78757               8                   6                   6          2
# 78758               5                   2                   6          1
# 78759               5                   2                   6          1
# 78760               7                   6                   6          1
# 78761               8                   8                   7          1
#
#        language  marital_status  race  first_careunit  last_careunit  \
# 0             1               3    28               9              9
# 1             1               3    28               9              9
# 2             1               3    28               9              9
# 3             1               3    28               2              2
# 5             1               1    28               9              9
# ...         ...             ...   ...             ...            ...
# 78757         1               1    28               9              9
# 78758         1               0    28               9              9
# 78759         1               0    28               9              9
# 78760         1               0    28               9              9
# 78761         1               0    28               9              9
#
#        curr_service  gender  anchor_age  anchor_year_group  BMI (kg/m2)  \
# 0                 7       0          52                  2    18.537500
# 1                 7       0          52                  2    18.537500
# 2                 7       0          52                  2    18.537500
# 3                 7       0          52                  2    18.537500
# 5                 7       1          72                  3    24.400000
# ...             ...     ...         ...                ...          ...
# 78757            10       0          31                  1    20.800000
# 78758             7       0          46                  0    32.460377
# 78759            15       0          46                  0    32.460377
# 78760            12       0          46                  0    32.460377
# 78761             9       0          46                  0    32.460377
#
#        Weight (Lbs)
# 0         93.104000
# 1         93.104000
# 2         93.104000
# 3         93.104000
# 5        170.000000
# ...             ...
# 78757    115.400000
# 78758    184.133962
# 78759    184.133962
# 78760    184.133962
# 78761    184.133962
#
# [47555 rows x 15 columns]

# %%
X['BMI (kg/m2)']=X['BMI (kg/m2)'].astype(float)
X['Weight (Lbs)']=X['Weight (Lbs)'].astype(float)
X
# Out:
#        admission_type  admission_location  discharge_location  insurance  \
# 0                   8                   8                   6          2
# 1                   5                   2                   6          0
# 2                   5                   2                   8          0
# 3                   5                   2                   6          0
# 5                   5                  10                   7          1
# ...               ...                 ...                 ...        ...
# 78757               8                   6                   6          2
# 78758               5                   2                   6          1
# 78759               5                   2                   6          1
# 78760               7                   6                   6          1
# 78761               8                   8                   7          1
#
#        language  marital_status  race  first_careunit  last_careunit  \
# 0             1               3    28               9              9
# 1             1               3    28               9              9
# 2             1               3    28               9              9
# 3             1               3    28               2              2
# 5             1               1    28               9              9
# ...         ...             ...   ...             ...            ...
# 78757         1               1    28               9              9
# 78758         1               0    28               9              9
# 78759         1               0    28               9              9
# 78760         1               0    28               9              9
# 78761         1               0    28               9              9
#
#        curr_service  gender  anchor_age  anchor_year_group  BMI (kg/m2)  \
# 0                 7       0          52                  2    18.537500
# 1                 7       0          52                  2    18.537500
# 2                 7       0          52                  2    18.537500
# 3                 7       0          52                  2    18.537500
# 5                 7       1          72                  3    24.400000
# ...             ...     ...         ...                ...          ...
# 78757            10       0          31                  1    20.800000
# 78758             7       0          46                  0    32.460377
# 78759            15       0          46                  0    32.460377
# 78760            12       0          46                  0    32.460377
# 78761             9       0          46                  0    32.460377
#
#        Weight (Lbs)
# 0         93.104000
# 1         93.104000
# 2         93.104000
# 3         93.104000
# 5        170.000000
# ...             ...
# 78757    115.400000
# 78758    184.133962
# 78759    184.133962
# 78760    184.133962
# 78761    184.133962
#
# [47555 rows x 15 columns]

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
columns = X.columns
X_final = imputer.fit_transform(X)
X_final=pd.DataFrame(X_final, columns=columns)
X_final
# Out:
#        admission_type  admission_location  discharge_location  insurance  \
# 0                 8.0                 8.0                 6.0        2.0
# 1                 5.0                 2.0                 6.0        0.0
# 2                 5.0                 2.0                 8.0        0.0
# 3                 5.0                 2.0                 6.0        0.0
# 4                 5.0                10.0                 7.0        1.0
# ...               ...                 ...                 ...        ...
# 47550             8.0                 6.0                 6.0        2.0
# 47551             5.0                 2.0                 6.0        1.0
# 47552             5.0                 2.0                 6.0        1.0
# 47553             7.0                 6.0                 6.0        1.0
# 47554             8.0                 8.0                 7.0        1.0
#
#        language  marital_status  race  first_careunit  last_careunit  \
# 0           1.0             3.0  28.0             9.0            9.0
# 1           1.0             3.0  28.0             9.0            9.0
# 2           1.0             3.0  28.0             9.0            9.0
# 3           1.0             3.0  28.0             2.0            2.0
# 4           1.0             1.0  28.0             9.0            9.0
# ...         ...             ...   ...             ...            ...
# 47550       1.0             1.0  28.0             9.0            9.0
# 47551       1.0             0.0  28.0             9.0            9.0
# 47552       1.0             0.0  28.0             9.0            9.0
# 47553       1.0             0.0  28.0             9.0            9.0
# 47554       1.0             0.0  28.0             9.0            9.0
#
#        curr_service  gender  anchor_age  anchor_year_group  BMI (kg/m2)  \
# 0               7.0     0.0        52.0                2.0    18.537500
# 1               7.0     0.0        52.0                2.0    18.537500
# 2               7.0     0.0        52.0                2.0    18.537500
# 3               7.0     0.0        52.0                2.0    18.537500
# 4               7.0     1.0        72.0                3.0    24.400000
# ...             ...     ...         ...                ...          ...
# 47550          10.0     0.0        31.0                1.0    20.800000
# 47551           7.0     0.0        46.0                0.0    32.460377
# 47552          15.0     0.0        46.0                0.0    32.460377
# 47553          12.0     0.0        46.0                0.0    32.460377
# 47554           9.0     0.0        46.0                0.0    32.460377
#
#        Weight (Lbs)
# 0         93.104000
# 1         93.104000
# 2         93.104000
# 3         93.104000
# 4        170.000000
# ...             ...
# 47550    115.400000
# 47551    184.133962
# 47552    184.133962
# 47553    184.133962
# 47554    184.133962
#
# [47555 rows x 15 columns]

# %%
nax=X_final.isna().sum()
nax
# Out:
# admission_type        0
# admission_location    0
# discharge_location    0
# insurance             0
# language              0
# marital_status        0
# race                  0
# first_careunit        0
# last_careunit         0
# curr_service          0
# gender                0
# anchor_age            0
# anchor_year_group     0
# BMI (kg/m2)           0
# Weight (Lbs)          0
# dtype: int64

# %%
X=X_final.iloc[:,:-2].astype(int)
X['BMI (kg/m2)']=X_final['BMI (kg/m2)']
X['Weight (Lbs)']=X_final['Weight (Lbs)']
X
# Out:
#        admission_type  admission_location  discharge_location  insurance  \
# 0                   8                   8                   6          2
# 1                   5                   2                   6          0
# 2                   5                   2                   8          0
# 3                   5                   2                   6          0
# 4                   5                  10                   7          1
# ...               ...                 ...                 ...        ...
# 47550               8                   6                   6          2
# 47551               5                   2                   6          1
# 47552               5                   2                   6          1
# 47553               7                   6                   6          1
# 47554               8                   8                   7          1
#
#        language  marital_status  race  first_careunit  last_careunit  \
# 0             1               3    28               9              9
# 1             1               3    28               9              9
# 2             1               3    28               9              9
# 3             1               3    28               2              2
# 4             1               1    28               9              9
# ...         ...             ...   ...             ...            ...
# 47550         1               1    28               9              9
# 47551         1               0    28               9              9
# 47552         1               0    28               9              9
# 47553         1               0    28               9              9
# 47554         1               0    28               9              9
#
#        curr_service  gender  anchor_age  anchor_year_group  BMI (kg/m2)  \
# 0                 7       0          52                  2    18.537500
# 1                 7       0          52                  2    18.537500
# 2                 7       0          52                  2    18.537500
# 3                 7       0          52                  2    18.537500
# 4                 7       1          72                  3    24.400000
# ...             ...     ...         ...                ...          ...
# 47550            10       0          31                  1    20.800000
# 47551             7       0          46                  0    32.460377
# 47552            15       0          46                  0    32.460377
# 47553            12       0          46                  0    32.460377
# 47554             9       0          46                  0    32.460377
#
#        Weight (Lbs)
# 0         93.104000
# 1         93.104000
# 2         93.104000
# 3         93.104000
# 4        170.000000
# ...             ...
# 47550    115.400000
# 47551    184.133962
# 47552    184.133962
# 47553    184.133962
# 47554    184.133962
#
# [47555 rows x 15 columns]

# %%
y1=df_merged_final['Inpatient_Flow']
y2=df_merged_final['los']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y1_train, y1_test = train_test_split(X, y1, test_size=0.2, random_state=1502)

X_train, X_test, y2_train, y2_test = train_test_split(X, y2, test_size=0.2, random_state=1502)

# %%
X_train
# Out:
#        admission_type  admission_location  discharge_location  insurance  \
# 43198               5                   2                   6          1
# 264                 7                   6                   6          1
# 26239               6                   8                  11          1
# 19685               6                   2                   6          2
# 39077               8                   8                   6          2
# ...               ...                 ...                 ...        ...
# 25333               4                   2                  13          1
# 9145                4                   6                  13          2
# 41404               5                   2                   6          2
# 45105               7                   6                   7          1
# 21618               4                   2                  13          2
#
#        language  marital_status  race  first_careunit  last_careunit  \
# 43198         1               2    28               9              9
# 264           0               1    28               9              9
# 26239         1               3    28               9              9
# 19685         1               2    14               9              9
# 39077         1               1     9               9              9
# ...         ...             ...   ...             ...            ...
# 25333         1               1    28               9              9
# 9145          1               1    24               9              9
# 41404         1               1    28               2              2
# 45105         1               1    28               9              9
# 21618         1               2    28               9              9
#
#        curr_service  gender  anchor_age  anchor_year_group  BMI (kg/m2)  \
# 43198             8       1          63                  2    20.100000
# 264              15       0          66                  2    21.525000
# 26239            12       0          91                  3    23.600000
# 19685             7       1          42                  0    23.958333
# 39077            15       0          20                  0    37.200000
# ...             ...     ...         ...                ...          ...
# 25333             7       0          46                  0    29.381053
# 9145              7       1          79                  2    39.516667
# 41404             7       1          57                  1    27.605128
# 45105            12       0          63                  2    32.457143
# 21618             7       0          26                  0    21.975000
#
#        Weight (Lbs)
# 43198    134.400000
# 264      118.380556
# 26239    129.210000
# 19685    168.240606
# 39077    208.600000
# ...             ...
# 25333    165.769583
# 9145     254.086667
# 41404    200.443231
# 45105    187.899524
# 21618    120.239167
#
# [38044 rows x 15 columns]

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error

# %%
num_samples = 38044
input_dim = 15

# Define the multi-task neural network model with shared layers and task-specific layers
def create_multi_task_model(input_dim):
    input_layer = tf.keras.layers.Input(shape=(input_dim,))
    shared_layer1 = tf.keras.layers.Dense(15, activation='relu')(input_layer)

    # Task 1-specific layer (Binary Classification)
    class_specific_layer = tf.keras.layers.Dense(5, activation='relu')(shared_layer1)
    class_output = tf.keras.layers.Dense(1, activation='sigmoid', name='class_output')(class_specific_layer)

    # Task 2-specific layer (Regression)
    reg_specific_layer = tf.keras.layers.Dense(15, activation='relu')(shared_layer1)
    reg_output = tf.keras.layers.Dense(1, activation='relu', name='reg_output')(reg_specific_layer)

    model = tf.keras.models.Model(inputs=input_layer, outputs=[class_output, reg_output])

    return model

# Create the multi-task model
model = create_multi_task_model(input_dim)

# Compile the model with appropriate loss functions for each task
model.compile(optimizer='adam',
              loss=['binary_crossentropy', 'mean_squared_error'],
              metrics={'class_output': 'accuracy', 'reg_output': 'mae'})

# Train the multi-task model
model.fit(X_train,
        {'class_output': y1_train, 'reg_output': y2_train},
        epochs=20, batch_size=32)

# Make predictions on the test data
class_predictions, reg_predictions = model.predict(X_test)

# Evaluate the model's performance on each task
class_accuracy = accuracy_score(y1_test, np.round(class_predictions).flatten())
reg_mae = mean_absolute_error(y2_test, reg_predictions.flatten())

print("Classification Accuracy:", class_accuracy)
print("Regression Mean Absolute Error:", reg_mae)
# Out:
# Epoch 1/20
# 1189/1189 [==============================] - 5s 3ms/step - loss: 12.4826 - class_output_loss: 3.1021 - reg_output_loss: 9.3805 - class_output_accuracy: 0.8264 - reg_output_mae: 2.1987
# Epoch 2/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 4.3901 - class_output_loss: 0.2020 - reg_output_loss: 4.1881 - class_output_accuracy: 0.9385 - reg_output_mae: 1.6160
# Epoch 3/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 4.2739 - class_output_loss: 0.1247 - reg_output_loss: 4.1492 - class_output_accuracy: 0.9653 - reg_output_mae: 1.6024
# Epoch 4/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 4.1831 - class_output_loss: 0.0886 - reg_output_loss: 4.0945 - class_output_accuracy: 0.9760 - reg_output_mae: 1.5927
# Epoch 5/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 4.0733 - class_output_loss: 0.0717 - reg_output_loss: 4.0016 - class_output_accuracy: 0.9794 - reg_output_mae: 1.5749
# Epoch 6/20
# 1189/1189 [==============================] - 4s 4ms/step - loss: 3.9714 - class_output_loss: 0.0637 - reg_output_loss: 3.9077 - class_output_accuracy: 0.9812 - reg_output_mae: 1.5545
# Epoch 7/20
# 1189/1189 [==============================] - 3s 2ms/step - loss: 3.8088 - class_output_loss: 0.0589 - reg_output_loss: 3.7499 - class_output_accuracy: 0.9824 - reg_output_mae: 1.5207
# Epoch 8/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 3.7173 - class_output_loss: 0.0557 - reg_output_loss: 3.6616 - class_output_accuracy: 0.9831 - reg_output_mae: 1.5019
# Epoch 9/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 3.6862 - class_output_loss: 0.0531 - reg_output_loss: 3.6331 - class_output_accuracy: 0.9834 - reg_output_mae: 1.4947
# Epoch 10/20
# 1189/1189 [==============================] - 4s 4ms/step - loss: 3.6347 - class_output_loss: 0.0526 - reg_output_loss: 3.5821 - class_output_accuracy: 0.9843 - reg_output_mae: 1.4852
# Epoch 11/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 3.5956 - class_output_loss: 0.0519 - reg_output_loss: 3.5438 - class_output_accuracy: 0.9843 - reg_output_mae: 1.4767
# Epoch 12/20
# 1189/1189 [==============================] - 3s 2ms/step - loss: 3.5774 - class_output_loss: 0.0519 - reg_output_loss: 3.5255 - class_output_accuracy: 0.9846 - reg_output_mae: 1.4694
# Epoch 13/20
# 1189/1189 [==============================] - 3s 2ms/step - loss: 3.5495 - class_output_loss: 0.0515 - reg_output_loss: 3.4981 - class_output_accuracy: 0.9849 - reg_output_mae: 1.4633
# Epoch 14/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 3.5144 - class_output_loss: 0.0511 - reg_output_loss: 3.4633 - class_output_accuracy: 0.9848 - reg_output_mae: 1.4543
# Epoch 15/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 3.5025 - class_output_loss: 0.0503 - reg_output_loss: 3.4522 - class_output_accuracy: 0.9853 - reg_output_mae: 1.4511
# Epoch 16/20
# 1189/1189 [==============================] - 3s 3ms/step - loss: 3.4593 - class_output_loss: 0.0500 - reg_output_loss: 3.4093 - class_output_accuracy: 0.9854 - reg_output_mae: 1.4357
# Epoch 17/20
# 1189/1189 [==============================] - 3s 2ms/step - loss: 3.4107 - class_output_loss: 0.0511 - reg_output_loss: 3.3596 - class_output_accuracy: 0.9854 - reg_output_mae: 1.4193
# Epoch 18/20
# 1189/1189 [==============================] - 3s 2ms/step - loss: 3.3818 - class_output_loss: 0.0537 - reg_output_loss: 3.3281 - class_output_accuracy: 0.9843 - reg_output_mae: 1.4100
# Epoch 19/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 3.3527 - class_output_loss: 0.0521 - reg_output_loss: 3.3005 - class_output_accuracy: 0.9848 - reg_output_mae: 1.4026
# Epoch 20/20
# 1189/1189 [==============================] - 4s 3ms/step - loss: 3.3228 - class_output_loss: 0.0524 - reg_output_loss: 3.2704 - class_output_accuracy: 0.9847 - reg_output_mae: 1.3965
# 298/298 [==============================] - 1s 1ms/step
# Classification Accuracy: 0.9782357270528861
# Regression Mean Absolute Error: 1.3236973437459771

# %%
from sklearn.linear_model import LinearRegression

linear_regressor = LinearRegression()

# Train the model on the training data
linear_regressor.fit(X_train, y2_train)

# Make predictions on the test data
y2_pred = linear_regressor.predict(X_test)

lr_score_MAE = mean_absolute_error(y2_test, y2_pred)
print(f'MAE Score on Test set: {lr_score_MAE:0.2f}')
# Out:
# MAE Score on Test set: 1.53

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Create the KNN Regressor model
knn_model = KNeighborsRegressor(n_neighbors=10, weights='uniform')

# Train the KNN Regressor model
knn_model.fit(X_train, y2_train)

# Make predictions on the test data
y2_pred = knn_model.predict(X_test)

# Evaluate the model's performance
mae = mean_absolute_error(y2_test, y2_pred)

print("Mean Squared Error:", mae)
# Out:
# Mean Squared Error: 1.4519833321650955
